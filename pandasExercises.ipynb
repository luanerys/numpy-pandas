# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
vgsales = pd.read_csv(r'C:\Users\Luana\Downloads\numpy-pandas_LuanaAtv2\dataset\vgsales.csv')

# %%
vgsales.agg({'NA_Sales': ['min', 'max', 'median'],
             'EU_Sales': ['min', 'max', 'median',],
             'JP_Sales': ['min', 'max', 'median']})
# Out:
#         NA_Sales  EU_Sales  JP_Sales
# min         0.00      0.00      0.00
# max        41.49     29.02     10.22
# median      2.14      1.39      0.15

# %%
vgsales.groupby(['Rank','Name'])['Global_Sales'].mean()
# Out:
# Rank  Name
# 1     Wii Sports                          82.74
# 2     Super Mario Bros.                   40.24
# 3     Mario Kart Wii                      35.82
# 4     Wii Sports Resort                   33.00
# 5     Pokemon Red/Pokemon Blue            31.37
#                                           ...
# 506   Call of Duty: Ghosts                 2.86
# 507   Madden NFL 13                        2.86
# 508   The Elder Scrolls III: Morrowind     2.86
# 509   Mortal Kombat                        2.85
# 510   F-Zero                               2.85
# Name: Global_Sales, Length: 510, dtype: float64

# %%
vgsales.groupby('Platform')['Publisher'].count()
# Out:
# Platform
# 2600     3
# 3DS     17
# DS      40
# GB      17
# GBA     10
# GC       6
# GEN      2
# N64     14
# NES     17
# PC      15
# PS      47
# PS2     82
# PS3     57
# PS4     27
# PSP     10
# SNES    15
# Wii     41
# WiiU     7
# X360    65
# XB       4
# XOne    13
# Name: Publisher, dtype: int64

# %%
#usando regex para busca
import re
vgsales.loc[vgsales['Platform'].str.contains('Wii',flags=re.I, regex=True)].head()
# Out:
#    Rank                       Name Platform    Year     Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0    Sports  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 7     8                   Wii Play      Wii  2006.0      Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0  Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62

# %%
vgsales.loc[vgsales['Name'].str.contains('^ca[a-z]*', flags=re.I,regex=True)]
# Out:
#      Rank                            Name Platform    Year    Genre  \
# 29     30  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 31     32         Call of Duty: Black Ops     X360  2010.0  Shooter
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 34     35      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 35     36      Call of Duty: Black Ops II     X360  2012.0  Shooter
# 36     37  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 37     38  Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
# 40     41         Call of Duty: Black Ops      PS3  2010.0  Shooter
# 55     56  Call of Duty: Modern Warfare 2      PS3  2009.0  Shooter
# 61     62            Call of Duty: Ghosts     X360  2013.0  Shooter
# 67     68            Call of Duty: Ghosts      PS3  2013.0  Shooter
# 70     71  Call of Duty 4: Modern Warfare     X360  2007.0  Shooter
# 93     94  Call of Duty: Advanced Warfare      PS4  2014.0  Shooter
# ...

# %%
vgsales.groupby(['Name']).mean().sort_values(['NA_Sales','Global_Sales'],ascending=False)
# Out:
#                                                     Rank    Year  NA_Sales  \
# Name
# Wii Sports                                           1.0  2006.0     41.49
# Duck Hunt                                           10.0  1984.0     26.93
# Super Mario Bros.                                  101.5  1992.0     16.24
# Mario Kart Wii                                       3.0  2008.0     15.85
# Wii Sports Resort                                    4.0  2009.0     15.75
# ...                                                  ...     ...       ...
# Monster Hunter Freedom 3                           215.0  2010.0      0.00
# Friend Collection                                  339.0  2009.0      0.00
# Monster Hunter 4                                   384.0  2013.0      0.00
# English Training: Have Fun Improving Your Skills!  403.0  2006.0      0.00
# Dragon Quest VI: Maboroshi no Daichi               427.0  1995.0      0.00
#
# ...

# %%
data = vgsales.set_index(['Year', 'Genre'])
data.head(10)
# Out:
#                      Rank                       Name Platform Publisher  \
# Year   Genre
# 2006.0 Sports           1                 Wii Sports      Wii  Nintendo
# 1985.0 Platform         2          Super Mario Bros.      NES  Nintendo
# 2008.0 Racing           3             Mario Kart Wii      Wii  Nintendo
# 2009.0 Sports           4          Wii Sports Resort      Wii  Nintendo
# 1996.0 Role-Playing     5   Pokemon Red/Pokemon Blue       GB  Nintendo
# 1989.0 Puzzle           6                     Tetris       GB  Nintendo
# 2006.0 Platform         7      New Super Mario Bros.       DS  Nintendo
#        Misc             8                   Wii Play      Wii  Nintendo
# 2009.0 Platform         9  New Super Mario Bros. Wii      Wii  Nintendo
# 1984.0 Shooter         10                  Duck Hunt      NES  Nintendo
#
#                      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year   Genre
# ...

# %%
plt.figure(figsize=(15, 10))
ax = sbn.countplot(x="Platform", data=vgsales)
plt.xticks(rotation= 90)
plt.xlabel('Platform')
plt.ylabel('Total')
plt.title("Total games by platform")
# Out:
# Text(0.5, 1.0, 'Total games by platform')
